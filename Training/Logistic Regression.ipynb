# %% [markdown]
# ### Logistic Regression
# ##### Classification Problem
#
# Targets -> categorical
#
# Accuracy =(TP+TN)/(TP+TN+FP+FN)
#
# but accuracy is not a good predictor of an imbalanced data model
#
# We therefore use *Precision* and *recall* as they handle imbalanced data efficiently
#
# #### Precision
# It is used when avoiding false positives is more essential than encountering false negatives
#
# precision = predictions actually positive / Total Predicted Positive
#
# precision = TP/(TP+FP)
#
# #### Recall
# It is used when avoiding false negatives is prioritized over encountering false positives.
#
# recall = predictions actually positive/ total actual positive
#
# recall = TP/(TP+FN)
#
# ###### _Precision is inverse to Recall_
#
# #### F1 = harmonic Mean
# F1 = 2/((1/Precision)+(1/Recall))
#
# Higher the F1 score, better the model
#
# F1 is maximum when precision = recall

# %% [markdown]
# * If precision, Recall or F1 Score yield the same result, then to ditinguish which is better, we use -
# ##### Log loss
# The cost funtion of the Logistic Regression
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### AOC-ROC Curve
# -performance measurement for the classification problems at various thresholds settings.
#
# -AUC ROC is not suitable for imbalanced data
#
# * AUC - Area Under Curve
# * ROC - Reciever Operating Characteristics
#
# heigher the AUC ROC, better the model
#
# ##### If the AUC-ROC is >0.95, there could be something wrong with the model or the dataset
#
# - FPR (False Positive Rate) = FP/(TN + FP)
# - TPR (True Positive Rate)  = TP/(TP + FN)
#
# ##### Steps :
# 1. Arrange the predicted probabilities in descending order
# 2. Take the first value as a threshold and the classes are predicted based on this threshold
# 3. Calculate the TPR and FPR Values
#
# ![image-2.png](attachment:image-2.png)
