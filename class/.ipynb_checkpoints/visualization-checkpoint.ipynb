# %%
import matplotlib.pyplot as plt
plt.axis([0, 5, 0, 20])
plt.title('My first plot')
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.show()

# %%
import math
import numpy as np
t = np.arange(0, 2.5, 0.1)
y1 = np.sin(math.pi*t)
y2 = np.sin(math.pi*t+math.pi/2)
y3 = np.sin(math.pi*t-math.pi/2)
plt.plot(t, y1, 'b--', t, y2, 'g', t, y3,'r-.',linewidth=4.0)
# Out:
# [<matplotlib.lines.Line2D at 0x167eaf98848>,
#  <matplotlib.lines.Line2D at 0x167eaf8e1c8>,
#  <matplotlib.lines.Line2D at 0x167eaf9b208>]

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0, 5, 0.1)
y1 = np.sin(2*np.pi*t)
y2 = np.sin(2*np.pi*t)
plt.subplot(211)
plt.plot(t, y1,'b-.')
plt.subplot(212)
plt.plot(t, y2, 'r--')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.axis([0,5,0,20])
plt.title('My first plot',loc='left', fontstyle='italic', fontsize=20)
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='Times New Roman')
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.show()
