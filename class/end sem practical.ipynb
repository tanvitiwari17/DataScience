# %%
import math
import matplotlib.pyplot as plt
import numpy

x_cord=list(range(0,16))

casino_1=[34.784,34.52,37.16,34.112,34.032,29.464,33.352,30.536,34.76,32.568,34.592,33.76,34.152,34.208,30.192,85.08]
casino_2=[39.784,42.144,38.288,39.68,40.784,42.328,38.648,41.296,40.376,43.224,35.872,39.504,41.144,37.328,45.64,88.504]
casino_3=[48.096,43.912,45.76,45.112,46.744,43.864,47.264,48.112,45.76,44.576,45.504,46.328,44.448,46.432,48.472,91.272]
plt.suptitle("End sem practical")
plt.subplot(131)
plt.bar(x_cord, casino_1,color='g')
plt.text(2,60,max(casino_1),fontsize=12,bbox={'facecolor':'green', 'alpha':0.2})

plt.subplot(132)
plt.bar(x_cord, casino_2,color='b')
plt.text(2,60,max(casino_2),fontsize=12,bbox={'facecolor':'blue', 'alpha':0.2})
plt.subplot(133)

plt.bar(x_cord, casino_3,color='r')
plt.text(2,60,max(casino_3),fontsize=12,bbox={'facecolor':'red', 'alpha':0.2})

plt.show()
